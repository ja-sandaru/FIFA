# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("results.csv")
data
# Out:
#              date         home_team             away_team  home_score  \
# 0        2/3/1900          Scotland                 Wales           5
# 1       2/24/1900             Wales      Northern Ireland           2
# 2        3/3/1900  Northern Ireland              Scotland           0
# 3       3/17/1900  Northern Ireland               England           0
# 4       3/26/1900             Wales               England           1
# ...           ...               ...                   ...         ...
# 48759  12/12/2025            Jordan                  Iraq           1
# 48760  12/12/2025           Algeria  United Arab Emirates           1
# 48761  12/15/2025           Morocco  United Arab Emirates           3
# 48762  12/15/2025      Saudi Arabia                Jordan           0
# 48763  12/18/2025            Jordan               Morocco           2
#
#        away_score                 tournament       city   country  neutral  \
# ...

# %%
x = data[["date","home_team","away_team","Result_team1"]]
x.tail()
# Out:
#              date     home_team             away_team Result_team1
# 48759  12/12/2025        Jordan                  Iraq          Win
# 48760  12/12/2025       Algeria  United Arab Emirates         Draw
# 48761  12/15/2025       Morocco  United Arab Emirates          Win
# 48762  12/15/2025  Saudi Arabia                Jordan         Lose
# 48763  12/18/2025        Jordan               Morocco         Lose

# %%
data1 = pd.read_csv("dataset2.csv")
data1
# Out:
#         Date                 Match      Team1     Team2  Team1_rank  \
# 0    2002/06   2002FrancevsSenagal     France   Senegal           1
# 1    2002/07  2002UruguayvsDenmark    Uruguay   Denmark          24
# 2    2002/07  2002DenmarkvsSenegal    Denmark   Senegal          20
# 3    2002/07   2002FrancevsUruguay     France   Uruguay           1
# 4    2002/07   2002DenmarkvsFrance    Denmark    France          20
# ..       ...                   ...        ...       ...         ...
# 378  2022/11          2022MorvsPor    Morocco  Portugal          22
# 379  2022/11          2022ArgvsCro  Argentina   Croatia           3
# 380  2022/11          2022FravsMor     France   Morocco           4
# 381  2022/11   2022_Final_ArgvsFra  Argentina    France           3
# 382  2022/11          2022CrovsMor    Croatia   Morocco          12
#
#      Team2_rank  Team1_Star_Player_Count  Team1_Top100_players  \
# 0            42                        1                     6
# ...

# %%
def get_recent(row):
    input_date = pd.to_datetime(row["Date"])
    fi_team1 = row["Team1"]
    fi_team2 = row["Team2"]


    date_fill = x[pd.to_datetime(data1["date"]) < input_date ]
    clear_data = date_fill[fi_team1].tail()
    
    


clran = data1.apply(get_recent, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kalin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'France'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 9
# ...
